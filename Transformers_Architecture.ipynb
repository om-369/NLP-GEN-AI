# %%
from IPython.display import display, Image

# %%
display(Image("/content/Roll_out.jpg", height=300))

# %%
display(Image("/content/transformers.jpeg", height=300))

# %% [markdown]
# ###Inputs

# %%
#Encoder

Inputs
# movie was long but not good
# 55     900  622 90  100  55

# %%
Input Embedding
#in paper --> 512 dimentional vector

movie (55) --> [0.33, 99,22, 12..., ] + []  --> movie at postion

# %%
Positional Encoding

# %%
#Importing required library
import numpy as np
import matplotlib.pyplot as plt


# Creating x axis with range and y axis with Sine
# Function for Plotting Sine Graph
x = np.arange(0, 5*np.pi, 0.1)
y = np.sin(x)


# Plotting Sine Graph
plt.plot(x, y, color='green')
# plt.show()

# %%
#Importing required library
import numpy as np
import matplotlib.pyplot as plt


# Creating x axis with range and y axis with Sine
# Function for Plotting Sine Graph
x = np.arange(0, 10*np.pi, 0.1)
y = np.sin(x)


# Plotting Sine Graph
plt.plot(x, y, color='green')
# plt.show()

# %%
display(Image("/content/positional_embedding_formula.png"))

# %%
movie (55) --> [0.33, 99,22, 12..., ] + []  --> movie at postion

# %%
#Rope --> rotary positional encoding

# %% [markdown]
# #Encoder

# %%
# movie was long but not good

# movie was not long but good

# %%
#Multi-head Attention
#Scaled dot product attention

# %%
display(Image("/content/Components-of-the-Multi-Head-Attention-Design-Vaswani-et-al-2017.jpg"))

# %% [markdown]
# ##Add & Norm

# %%
why Normalization :

1) Reduce bias
2) exploding
3) faster training
4) computational cost

# %%
# movie was not long but good

[55], [], [],

# %%
# layer normalization

movie --> [len(512)]

# %% [markdown]
# ##Residual Connection

# %%
# Why residual-connection :
preservation of earlier knowledge

vanishing gradiet

# %% [markdown]
# #Decoder

# %% [markdown]
# ##Masked Multi-head attention

# %%
#I crossed river to get to the bank.

# %%
            I crossed river to get to the bank.

 I          0   000000000000000000000000000000

 crossed    7   6     00000000000000000000000

 river       9   6      4     00000000000000

 to
..
..

# %%
#masked-multi head attention

all input values comes after perticular word(query) in sequence, attention score will be zero

# %%
# Cross

# %%
#linear & softmax

to predict probability of next word

# %%
#teacher forcing:
during training, even model predict wrong output in next, we'll pass correct output
