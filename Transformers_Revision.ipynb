# %%
#Encoder-Decoder Architecture

# %%
from IPython.display import Image, display

# %%
display(Image("/content/encoder-decoder-architecture.png"))

# %%
#Attention Mechanism

# %%
Additive attention
multiplicative attention

# %%
# apple is a great company

# %%
1) Tokenize --> vectorize

2) get score by dot product

--> scaling (sqrt(dk))

3) Noramize with softmax

4) weigh with orginal vectors

# %%
display(Image("/content/attention_for.png"))

# %%
display(Image("/content/self-attention.png", height=400))

# %%
display(Image("/content/cross-attention-in-transformer-architecture.png", height=400))

# %%
#transformers

# %%
display(Image("/content/transformers.jpeg", height=400))

# %%
# apple is a great company

 <sos> 100    567 1 789  765

# %%
#australia beats india in 2023 wordcup final

#india beats australia in 2023 wordcup final

# %%
#Positional Encoding :
