# %% [markdown]
# <a href="https://colab.research.google.com/github/om-369/NLP-GEN-AI/blob/main/Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display

# %%
display(Image("/content/transformers.jpeg"))

# %%
#Components of Transformer Architecture :

Input Embedding
Positional Embedding

Encoder :
  - Multi-head Attention
  - Residual Connection
  - Layer Normalization

  - Feed Forward Network

# %%
Output Embedding
Positional Embedding

Decoder :
  - Masked Multi-head Attention
  - Residual Connection
  - Layer Normalization

  - Multi-head Attention (Cross)

  - Feed Forward Network

  - Linear
  - Softmax
