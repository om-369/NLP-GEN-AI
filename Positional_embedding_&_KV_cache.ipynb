# %%
#How to read research paper

# %%
#main components of research paper

title
Abstract
introduction

author's work

conclusion
references

# %%
# https://arxiv-sanity-lite.com/

# %%
#Positional Embedding

# %%
1) Absolute positional embeddding

Learn
sinusoidal function (sin, cos)


#

# %%
from IPython.display import Image,display

# %%
display(Image("/content/positional_embedding_formula.png"))

# %%
#vectore are independent

# %%
#Relative positional embedding
T5

# %%
#Rotary positional embedding (RoPE)
llama2, Palm,

# %%
##KV cache

# %%
#muti-query attention (falcon)

# Gropup-query attention (llama2)

#sliding window attention (mistral)
