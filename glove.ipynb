# %% [markdown]
# <a href="https://colab.research.google.com/github/om-369/NLP-GEN-AI/blob/main/glove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
we are learning NLP today

# %%
CBOW
skipgram

# %%
morpholologically rich languages
oov

# %%
from IPython.display import Image, display

# %%
display(Image('/content/Glove.png'))

# %%
import gensim.downloader as download

# %%
glove_model = download.load('glove-twitter-25')

# %%
glove_model_100 = download.load('glove-twitter-100')

# %%
glove_model['cricket']
# Out:
# array([ 0.48169 , -0.066325, -0.44454 , -1.7274  , -1.0247  , -0.78493 ,
#         0.50351 , -0.65595 ,  0.56451 , -0.03321 , -0.14383 ,  0.71937 ,
#        -2.8215  ,  0.86131 ,  0.79783 , -0.49762 ,  0.044193, -0.24435 ,
#         0.051926,  1.0575  , -1.1741  ,  0.84042 ,  0.35934 , -1.0306  ,
#        -0.69021 ], dtype=float32)

# %%
len(glove_model['cricket'])
# Out:
# 25

# %%
download.info()['models'].keys()
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
glove_model.most_similar('cricket')
# Out:
# [('ncaa', 0.9297444224357605),
#  ('ipl', 0.9059461355209351),
#  ('nhl', 0.8933340907096863),
#  ('championship', 0.8847678899765015),
#  ('england', 0.8797493577003479),
#  ('wins', 0.8647024035453796),
#  ('indy', 0.8642993569374084),
#  ('auburn', 0.8611217141151428),
#  ('tna', 0.8553739786148071),
#  ('basketball', 0.8542302250862122)]

# %%
glove_model_100.most_similar('cricket')
# Out:
# [('england', 0.7279183864593506),
#  ('ipl', 0.6964269876480103),
#  ('lanka', 0.6902914643287659),
#  ('rugby', 0.6899120211601257),
#  ('sachin', 0.6841480135917664),
#  ('football', 0.6763507127761841),
#  ('batsman', 0.6658412218093872),
#  ('batting', 0.6636232137680054),
#  ('wales', 0.6626043319702148),
#  ('footy', 0.6583970785140991)]

# %%
glove_model.most_similar('politics')
# Out:
# [('political', 0.911410927772522),
#  ('government', 0.8940484523773193),
#  ('democracy', 0.8925500512123108),
#  ('policy', 0.8866463303565979),
#  ('laws', 0.8855860829353333),
#  ('education', 0.8852822184562683),
#  ('society', 0.8828974962234497),
#  ('states', 0.8730898499488831),
#  ('based', 0.8714849352836609),
#  ('corruption', 0.8699316382408142)]

# %%
glove_model_100.most_similar('politics')
# Out:
# [('political', 0.8287721872329712),
#  ('government', 0.7389174699783325),
#  ('policy', 0.7365120053291321),
#  ('democracy', 0.7328994870185852),
#  ('politicians', 0.718756377696991),
#  ('culture', 0.7154764533042908),
#  ('education', 0.7053471803665161),
#  ('society', 0.7052913904190063),
#  ('journalism', 0.7032076716423035),
#  ('congress', 0.6989056468009949)]

# %%
#  Text representation

# %%
#1. frequency
#2. prediction

# 1. frequency based
    #  OHE:  single word is presented 1 and other words zero
    # BOW/Countvectorizer : frequency of words (10 times or 20 times)
    # TF_IDF : tf - No.times particular term occured in doc / total no.of
              # wordsin doc
        #  IDF: log(total no.of docs / no.of docs with particular term)
        #  TF X  IDF
# 2.  prediction based:
    # Word2Vec : CBOW , Skipgram
            #  CBOW : predicts target word based on context words
            #  Skipgram : predicts context words based on target word
    # FastText : character based n-grams
    # Doc2vec : calculating emmbeddings for whole document
                  # (id of words are passed)
    #  Glove : based on cooccurence matrix and probabilites
