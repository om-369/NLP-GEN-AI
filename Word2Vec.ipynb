# %% [markdown]
# <a href="https://colab.research.google.com/github/om-369/NLP-GEN-AI/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Word2Vec

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('/content/drive/MyDrive/GoogleNews-vectors-negative300.bin',binary =True)

# %%
model['language']
# Out:
# array([ 2.30712891e-02,  1.68457031e-02,  1.54296875e-01,  1.27929688e-01,
#        -2.67578125e-01,  3.51562500e-02,  1.19140625e-01,  2.48046875e-01,
#         1.93359375e-01, -7.95898438e-02,  1.46484375e-01, -1.43554688e-01,
#        -3.04687500e-01,  3.46679688e-02, -1.85546875e-02,  1.06933594e-01,
#        -1.52343750e-01,  2.89062500e-01,  2.35595703e-02, -3.80859375e-01,
#         1.09863281e-01,  4.41406250e-01,  3.75976562e-02, -1.22680664e-02,
#         1.62353516e-02, -2.24609375e-01,  7.61718750e-02, -3.12500000e-02,
#        -2.16064453e-02,  1.49414062e-01, -4.02832031e-02, -4.46777344e-02,
#        -1.72851562e-01,  3.32031250e-02,  1.50390625e-01, -5.05371094e-02,
#         2.72216797e-02,  3.00781250e-01, -1.33789062e-01, -7.56835938e-02,
#         1.93359375e-01, -1.98242188e-01, -1.27563477e-02,  4.19921875e-01,
#        -2.19726562e-01,  1.44531250e-01, -3.93066406e-02,  1.94335938e-01,
# ...

# %%
len(model['language'])
# Out:
# 300

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('nlp')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-89e2a6106c21> in <cell line: 1>()
# ----> 1 model.most_similar('nlp')
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     839
#     840         # compute the weighted average of all keys
# --> 841         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842         all_keys = [
#     843             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516                 total_weight += abs(weights[idx])
# ...

# %%
model.most_similar('data')
# Out:
# [('Data', 0.7262316942214966),
#  ('datasets', 0.603030264377594),
#  ('dataset', 0.5796631574630737),
#  ('databases', 0.5450119972229004),
#  ('statistics', 0.537885844707489),
#  ('information', 0.5368290543556213),
#  ('database', 0.5325667262077332),
#  ('Data_System_IPEDS', 0.5222617983818054),
#  ('data.The', 0.5189103484153748),
#  ('OpenSpirit_enabled', 0.5174090266227722)]

# %%
model.doesnt_match(['data','statistics','cricket'])
# Out:
# 'cricket'

# %%
model.doesnt_match(['c','python','sql'])
# Out:
# 'python'

# %%
vector = model['king'] - model['man'] + model['women']
model.most_similar(vector)
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.535493791103363),
#  ('women', 0.5233659148216248),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.4995364248752594),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]

# %%
len(model['king'])
# Out:
# 300

# %%
len(model['queen'])
# Out:
# 300

# %%
vector = model['usd'] - model['usa'] + model['india']
model.most_similar(vector)
# Out:
# [('usd', 0.823950469493866),
#  ('usd_tonne', 0.5947383046150208),
#  ('usd_barrel', 0.5266844630241394),
#  ('troy_ounce', 0.5236445665359497),
#  ('brent_crude', 0.5154184103012085),
#  ('rupee', 0.5146457552909851),
#  ('US####_tonne', 0.5094329118728638),
#  ('#.####_usd', 0.5030604600906372),
#  ('usd_bbl', 0.5006808638572693),
#  ('palladium_XPD_=', 0.49892282485961914)]

# %%
vector = model['dollar'] - model['usa'] + model['india']
model.most_similar(vector)
# Out:
# [('dollar', 0.7422813177108765),
#  ('rupee', 0.6182144284248352),
#  ('greenback', 0.5907650589942932),
#  ('Japanese_Yen', 0.5396061539649963),
#  ('currency', 0.5178817510604858),
#  ('Indian_Rupee', 0.5045877695083618),
#  ('Dollar', 0.5006142258644104),
#  ('Rupee', 0.4995838403701782),
#  ('USdollar', 0.4986198842525482),
#  ('Malaysian_Ringgit', 0.49075984954833984)]
